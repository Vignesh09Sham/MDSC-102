# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
name = ["class", "Alcohol", "Malic acid", "Ash", "Alcalinity of ash", "Magnesium", "Total phenols", "Flavanoids", "Nonflavanoid phenols", "Proanthocyanins", "Color intensity", "Hue", "OD280/OD315 of diluted wines", "Proline"]
df = pd.read_csv("wine.data", names=name)
df
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(x = 'class', y ='Proline', data=df)
# Out:
# <Axes: xlabel='class', ylabel='Proline'>

# %%
def box_plots(df, target, variable, count):
    sns.boxplot(x = target, y = variable,data = df, hue="class")

# %%
j = 0
plt.figure(figsize=(30,30))
for i in name[1:]:
    j += 1
    plt.subplot(5,3,j)
    box_plots(df, "class", i, j)
    plt.title("Box plot for class and {}" .format(i))

plt.show()

# %% [markdown]
# #### Class and Alcohol
# * plot(1,1) : <br>
# Class 1 - The alcohol levels in this class seems to be normally skewed since the data is equally spread around the median. <br>
# Class 2 - The alcohol levels in this class is left skewed because most of the data is lying towards the left of the median. It also have some outliers. <br>
# Class 3 - The alcohol levels in this type of wine is right skewed since the right tail is longer than the left one.
#
# ### Class and Malic Acid
# * plot(1,2): <br>
# Class 1 - The Malic acid levels of this class is right skewed since most of the data is towards the right of the median. This class also has a lot of outliers. <br>
# Class 2: The Malic acid levels in this class are also right skewed. <br>
# Class 3 - The Malic acid levels in this class are normally skewed. <br>
#
# ### Class and Ash
# * plot(1,3): <br>
# Class 1 - The Ash levels are right skewed <br>
# Class 2 - The Ash levels are left skewed <br>
# Class 3 - The Ash levels are right skewed <br>
#
# ### Class and Alkalinity of ash
# * plot(2,1): <br>
# Class 1 - The alkalinity levels of ash are right skewed <br>
# Class 2 - The alkalinity levels of ash are right skewed <br>
# Class 3 - The alkalinity levels of ash are right skewed <br>
#
# ### Class and Magnesium
# * plot(2,2): <br>
# Class 1 - The magnesium levels are right skewed <br>
# Class 2 - The magnesium levels are right skewed with outliers <br>
# Class 3 - The magnesium levels are right skewed <br>
#
# ### Class and Total phenols
# * plot(2,3): <br>
# Class 1 - The Total pheneols levels are normally skewed <br>
# Class 2 - The Total pheneols levels are right skewed  <br>
# Class 3 - The Total pheneols levels are left skewed with outliers <br>
#
# ### Class and Flavavoids
# * plot(3,1): <br>
# Class 1 - normally skewed <br>
# Class 2 - right skewed with outliers <br>
# Class 3 - right  skewed with outliers <br>
#
# ### Class and Non-Flavanoid Phenols
# * plot(3,2): <br>
# Class 1 - left skewed with outliers <br>
# Class 2 - right skewed <br>
# Class 3 - left skewed with outliers <br>
#
# ### Class and Proanthocyanins
# * plot(3,3): <br>
# Class 1 - left skewed with outliers <br>
# Class 2 - normally skewed with outliers <br>
# Class 3 - right skewed with outliers <br>
#
# ### Class and Color Intensity
# * plot(4,1): <br>
# Class 1 - right skewed with outliers <br>
# Class 2 - right skewed <br>
# Class 3 - right skewed with outliers <br>
#
# ### Class and  Hue
# * plot(4,2): <br>
# Class 1 - left skewed <br>
# Class 2 - right skewed <br>
# Class 3 - right skewed <br>
#
# ### Class and OD280/OD315 of diluted wines
# * plot(4,3): <br>
# Class 1 - right skewed <br>
# Class 2 - left skewed <br>
# Class 3 - normally skewed  <br>
#
# ### Class and Proline
# * plot(5,1): <br>
# Class 1 - right skewed <br>
# Class 2 - right skewed <br>
# Class 3 - right skewed <br>

# %%
sns.histplot(df[df["class"] == 1]["Alcohol"], kde =True)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Count'>

# %%
sns.histplot(df[df["class"] == 2]["Alcohol"], kde =True)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Count'>

# %%
j = 0
plt.figure(figsize=(40,80))
for i in name[1:]:
    for k in range(1,4):
        j += 1
        plt.subplot(14,3,j)
        sns.histplot(df[df["class"] == k][i], kde =True)
        plt.title("Histogram for {} and class {}" .format(i,k))

plt.show()
